# %%
import pandas as pd
import numpy as np
import datetime
from time import strftime
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
#Loading the Dataset
health_data = pd.read_csv('Data.csv')

# %%
#Checking the data
health_data
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# 5       9.598513e+13        5626772      F  2016-04-27T08:36:51Z
# 6       7.336882e+14        5630279      F  2016-04-27T15:05:12Z
# 7       3.449833e+12        5630575      F  2016-04-27T15:39:58Z
# 8       5.639473e+13        5638447      F  2016-04-29T08:02:16Z
# 9       7.812456e+13        5629123      F  2016-04-27T12:48:25Z
# 10      7.345362e+14        5630213      F  2016-04-27T14:58:11Z
# 11      7.542951e+12        5620163      M  2016-04-26T08:44:12Z
# 12      5.666548e+14        5634718      F  2016-04-28T11:33:51Z
# ...

# %%
#Checking the rows and columns of the dataset
health_data.shape
# Out:
# (110527, 14)

# %%
#Checking the description of the data
health_data.info
# Out:
# <bound method DataFrame.info of            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# 5       9.598513e+13        5626772      F  2016-04-27T08:36:51Z
# 6       7.336882e+14        5630279      F  2016-04-27T15:05:12Z
# 7       3.449833e+12        5630575      F  2016-04-27T15:39:58Z
# 8       5.639473e+13        5638447      F  2016-04-29T08:02:16Z
# 9       7.812456e+13        5629123      F  2016-04-27T12:48:25Z
# 10      7.345362e+14        5630213      F  2016-04-27T14:58:11Z
# 11      7.542951e+12        5620163      M  2016-04-26T08:44:12Z
# 12      5.666548e+14        5634718      F  2016-04-28T11:33:51Z
# ...

# %%
#Checking the format of the data
# There are no null values therefore no cleaning is done here
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
# PatientId         110527 non-null float64
# AppointmentID     110527 non-null int64
# Gender            110527 non-null object
# ScheduledDay      110527 non-null object
# AppointmentDay    110527 non-null object
# Age               110527 non-null int64
# Neighbourhood     110527 non-null object
# Scholarship       110527 non-null int64
# Hipertension      110527 non-null int64
# Diabetes          110527 non-null int64
# Alcoholism        110527 non-null int64
# Handcap           110527 non-null int64
# SMS_received      110527 non-null int64
# No-show           110527 non-null object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
#Modifying the date and time into standard form
health_data['ScheduledDay'] = pd.to_datetime(health_data['ScheduledDay']).dt.date.astype('datetime64[ns]')
health_data['AppointmentDay'] = pd.to_datetime(health_data['AppointmentDay']).dt.date.astype('datetime64[ns]')

# %%
health_data.head(5)
# Out:
#       PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0  2.987250e+13        5642903      F   2016-04-29     2016-04-29   62
# 1  5.589978e+14        5642503      M   2016-04-29     2016-04-29   56
# 2  4.262962e+12        5642549      F   2016-04-29     2016-04-29   62
# 3  8.679512e+11        5642828      F   2016-04-29     2016-04-29    8
# 4  8.841186e+12        5642494      F   2016-04-29     2016-04-29   56
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA            0             1         0           0
# 1    JARDIM DA PENHA            0             0         0           0
# 2      MATA DA PRAIA            0             0         0           0
# 3  PONTAL DE CAMBURI            0             0         0           0
# 4    JARDIM DA PENHA            0             1         1           0
#
#    Handcap  SMS_received No-show
# 0        0             0      No
# 1        0             0      No
# ...

# %%
health_data['sch_weekday'] = health_data['ScheduledDay'].dt.dayofweek

# %%
health_data['app_weekday'] = health_data['AppointmentDay'].dt.dayofweek

# %%
health_data['sch_weekday'].value_counts()
# Out:
# 1    26168
# 2    24262
# 0    23085
# 4    18915
# 3    18073
# 5       24
# Name: sch_weekday, dtype: int64

# %%
health_data['app_weekday'].value_counts()
# Out:
# 2    25867
# 1    25640
# 0    22715
# 4    19019
# 3    17247
# 5       39
# Name: app_weekday, dtype: int64

# %%
health_data.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show',
#        'sch_weekday', 'app_weekday'],
#       dtype='object')

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 16 columns):
# PatientId         110527 non-null float64
# AppointmentID     110527 non-null int64
# Gender            110527 non-null object
# ScheduledDay      110527 non-null datetime64[ns]
# AppointmentDay    110527 non-null datetime64[ns]
# Age               110527 non-null int64
# Neighbourhood     110527 non-null object
# Scholarship       110527 non-null int64
# Hipertension      110527 non-null int64
# Diabetes          110527 non-null int64
# Alcoholism        110527 non-null int64
# Handcap           110527 non-null int64
# SMS_received      110527 non-null int64
# No-show           110527 non-null object
# sch_weekday       110527 non-null int64
# app_weekday       110527 non-null int64
# dtypes: datetime64[ns](2), float64(1), int64(10), object(3)
# memory usage: 13.5+ MB

# %%
#Changing some column names
health_data = health_data.rename(columns = {'Hipertension':'Hypertension','Handcap':'Handicap','SMS_received':'SMSReceived','No-show':'NoShow'})

# %%
health_data.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hypertension',
#        'Diabetes', 'Alcoholism', 'Handicap', 'SMSReceived', 'NoShow',
#        'sch_weekday', 'app_weekday'],
#       dtype='object')

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 16 columns):
# PatientId         110527 non-null float64
# AppointmentID     110527 non-null int64
# Gender            110527 non-null object
# ScheduledDay      110527 non-null datetime64[ns]
# AppointmentDay    110527 non-null datetime64[ns]
# Age               110527 non-null int64
# Neighbourhood     110527 non-null object
# Scholarship       110527 non-null int64
# Hypertension      110527 non-null int64
# Diabetes          110527 non-null int64
# Alcoholism        110527 non-null int64
# Handicap          110527 non-null int64
# SMSReceived       110527 non-null int64
# NoShow            110527 non-null object
# sch_weekday       110527 non-null int64
# app_weekday       110527 non-null int64
# dtypes: datetime64[ns](2), float64(1), int64(10), object(3)
# memory usage: 13.5+ MB

# %%
# Dropping some column names that have no significance
health_data.drop(['PatientId','AppointmentID','Neighbourhood'], axis = 1, inplace = True)

# %%
health_data
# Out:
#        Gender ScheduledDay AppointmentDay  Age  Scholarship  Hypertension  \
# 0           F   2016-04-29     2016-04-29   62            0             1
# 1           M   2016-04-29     2016-04-29   56            0             0
# 2           F   2016-04-29     2016-04-29   62            0             0
# 3           F   2016-04-29     2016-04-29    8            0             0
# 4           F   2016-04-29     2016-04-29   56            0             1
# 5           F   2016-04-27     2016-04-29   76            0             1
# 6           F   2016-04-27     2016-04-29   23            0             0
# 7           F   2016-04-27     2016-04-29   39            0             0
# 8           F   2016-04-29     2016-04-29   21            0             0
# 9           F   2016-04-27     2016-04-29   19            0             0
# 10          F   2016-04-27     2016-04-29   30            0             0
# 11          M   2016-04-26     2016-04-29   29            0             0
# ...

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 13 columns):
# Gender            110527 non-null object
# ScheduledDay      110527 non-null datetime64[ns]
# AppointmentDay    110527 non-null datetime64[ns]
# Age               110527 non-null int64
# Scholarship       110527 non-null int64
# Hypertension      110527 non-null int64
# Diabetes          110527 non-null int64
# Alcoholism        110527 non-null int64
# Handicap          110527 non-null int64
# SMSReceived       110527 non-null int64
# NoShow            110527 non-null object
# sch_weekday       110527 non-null int64
# app_weekday       110527 non-null int64
# dtypes: datetime64[ns](2), int64(9), object(2)
# memory usage: 11.0+ MB

# %%
#Descriptive Statistics of the dataset
health_data.describe()
# Out:
#                  Age    Scholarship   Hypertension       Diabetes  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean       37.088874       0.098266       0.197246       0.071865
# std        23.110205       0.297675       0.397921       0.258265
# min        -1.000000       0.000000       0.000000       0.000000
# 25%        18.000000       0.000000       0.000000       0.000000
# 50%        37.000000       0.000000       0.000000       0.000000
# 75%        55.000000       0.000000       0.000000       0.000000
# max       115.000000       1.000000       1.000000       1.000000
#
#           Alcoholism       Handicap    SMSReceived    sch_weekday  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.030400       0.022248       0.321026       1.851955
# std         0.171686       0.161543       0.466873       1.378520
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
#Plotting the target variables
health_data['NoShow'].value_counts().plot(kind = 'barh',figsize = (8,6), color = 'teal')
plt.xlabel("count", fontweight = 'bold')
plt.ylabel("Target Variable",fontweight = 'bold')
plt.title("Count of Target Variable per Category",fontweight = 'bold', y = 1.02);

# %%
#Calculating the percentage of appoitnments and no appontments
100*health_data['NoShow'].value_counts()/len(health_data['NoShow'])
# Out:
# No     79.806744
# Yes    20.193256
# Name: NoShow, dtype: float64

# %%
#The values representing the percerntages of appontments and no appointments
health_data['NoShow'].value_counts()
# Out:
# No     88208
# Yes    22319
# Name: NoShow, dtype: int64

# %%
#Checking whether the data contains missing values or not
missing = pd.DataFrame((health_data.isnull().sum())*100/health_data.shape[0]).reset_index()
plt.figure(figsize = (16,5))
ax = sns.pointplot('index',0,data = missing)
plt.xticks(rotation = 90,fontsize = 7)
plt.title("Percentage of Missing Values")
plt.ylabel("PERCENTAGE")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Data Cleaning

# %%
new_data = health_data.copy()

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 13 columns):
# Gender            110527 non-null object
# ScheduledDay      110527 non-null datetime64[ns]
# AppointmentDay    110527 non-null datetime64[ns]
# Age               110527 non-null int64
# Scholarship       110527 non-null int64
# Hypertension      110527 non-null int64
# Diabetes          110527 non-null int64
# Alcoholism        110527 non-null int64
# Handicap          110527 non-null int64
# SMSReceived       110527 non-null int64
# NoShow            110527 non-null object
# sch_weekday       110527 non-null int64
# app_weekday       110527 non-null int64
# dtypes: datetime64[ns](2), int64(9), object(2)
# memory usage: 11.0+ MB

# %% [markdown]
# ## As there is no missing values there is no Data Cleaning that is required

# %%
#Get the max tenure
print(health_data['Age'].max())
# Out:
# 115

# %%
#Grouping the tenure in bins of 12 months
labels = ["{0} - {1}".format(i, i + 20) for i in range(1,118, 20)]
health_data['Age_group'] = pd.cut(health_data.Age, range(1, 130, 20), right = False, labels = labels)

# %%
health_data.drop(['Age'], axis = 1, inplace = True)

# %% [markdown]
# # Data Exploration

# %%
list(health_data.columns)
# Out:
# ['Gender',
#  'ScheduledDay',
#  'AppointmentDay',
#  'Scholarship',
#  'Hypertension',
#  'Diabetes',
#  'Alcoholism',
#  'Handicap',
#  'SMSReceived',
#  'NoShow',
#  'sch_weekday',
#  'app_weekday',
#  'Age_group']

# %%
#Understanding the values of count of each columns and their count in respect to NoShow column 
for i, predictor in enumerate (health_data.drop(columns = ['NoShow'])):
    print('-'*10,predictor,'-'*10)
    print(health_data[predictor].value_counts())
    plt.figure(i)
    sns.countplot(data = health_data, x = predictor, hue = 'NoShow')
# Out:
# ---------- Gender ----------
# F    71840
# M    38687
# Name: Gender, dtype: int64
# ---------- ScheduledDay ----------
# 2016-05-03    4238
# 2016-05-02    4216
# 2016-05-16    4120
# 2016-05-05    4095
# 2016-05-10    4024
# 2016-05-09    3969
# 2016-04-29    3778
# 2016-05-11    3576
# 2016-05-04    3567
# 2016-05-30    3452
# 2016-05-17    3447
# 2016-05-24    3421
# 2016-05-06    3414
# 2016-05-12    3403
# 2016-05-18    3379
# 2016-05-19    3123
# 2016-05-20    3107
# 2016-05-13    3093
# 2016-05-25    2918
# 2016-05-31    2846
# 2016-06-01    2776
# 2016-06-02    2757
# 2016-04-28    2708
# 2016-06-03    2497
# 2016-04-26    2431
# 2016-06-06    2403
# 2016-04-27    2330
# 2016-04-25    2109
# 2016-04-20    1952
# 2016-06-07    1779
#               ...
# 2016-02-18       9
# 2015-12-15       7
# 2016-01-11       7
# 2016-02-11       7
# 2015-12-14       6
# 2016-01-22       6
# 2016-04-30       6
# 2016-01-25       5
# 2016-02-02       4
# 2016-01-05       4
# ...

# %%
health_data['NoShow'] = np.where(health_data.NoShow == 'Yes',1,0)

# %%
health_data.NoShow.value_counts()
# Out:
# 0    88208
# 1    22319
# Name: NoShow, dtype: int64

# %% [markdown]
# ## Converting all the categorical values into dummy variables

# %%
health_data_dummies = pd.get_dummies(health_data)
health_data_dummies.head()
# Out:
#   ScheduledDay AppointmentDay  Scholarship  Hypertension  Diabetes  \
# 0   2016-04-29     2016-04-29            0             1         0
# 1   2016-04-29     2016-04-29            0             0         0
# 2   2016-04-29     2016-04-29            0             0         0
# 3   2016-04-29     2016-04-29            0             0         0
# 4   2016-04-29     2016-04-29            0             1         1
#
#    Alcoholism  Handicap  SMSReceived  NoShow  sch_weekday  app_weekday  \
# 0           0         0            0       0            4            4
# 1           0         0            0       0            4            4
# 2           0         0            0       0            4            4
# 3           0         0            0       0            4            4
# 4           0         0            0       0            4            4
#
#    Gender_F  Gender_M  Age_group_1 - 21  Age_group_21 - 41  Age_group_41 - 61  \
# ...

# %% [markdown]
# ## Building a correlation of all predictors with NoShow

# %%
plt.figure(figsize = (20,8))
health_data_dummies.corr()['NoShow'].sort_values(ascending = False).plot(kind = 'bar', color = 'green')

# %%
plt.figure(figsize = (12,12))
sns.heatmap(health_data_dummies.corr(), cmap = "Paired")

# %% [markdown]
# ## Bivariate Analysis

# %%
new_df1_target0 = health_data.loc[health_data["NoShow"] == 0]
new_df1_target1 = health_data.loc[health_data["NoShow"] == 1]

# %%
def uniplot(df,col,title,hue = None):
    
    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"] = 20
    plt.rcParams['axes.titlesize'] = 22
    plt.rcParams['axes.titlepad'] = 30
    
    
    temp = pd.Series(data = hue)
    fig, ax = plt.subplots()
    width = len(df[col].unique()) + 7 + 4*len(temp.unique())
    fig.set_size_inches(width, 8)
    plt.xticks(rotation = 45)
    plt.yscale('log')
    plt.title(title)
    ax = sns.countplot(data = df, x = col, order = df[col].value_counts().index, hue = hue, palette = 'bright')
    
    plt.show()

# %%
uniplot(new_df1_target1, col = 'Hypertension',title = 'Distribution of Gender for NoShow Customers',hue = 'Gender')

# %%
uniplot(new_df1_target0, col = 'Hypertension',title = 'Distribution of Gender for NoShow Customers',hue = 'Gender')

# %%
uniplot(new_df1_target1, col = 'Age_group',title = 'Distribution of Age for NoShow Customers',hue = 'Gender')

# %%
uniplot(new_df1_target0, col = 'Age_group',title = 'Distribution of Age for NoShow Customers',hue = 'Gender')

# %%
uniplot(new_df1_target1, col = 'Scholarship',title = 'Distribution of Gender for NoShow Customers',hue = 'Gender')

# %%
uniplot(new_df1_target0, col = 'Scholarship',title = 'Distribution of Gender for NoShow Customers',hue = 'Gender')

# %%
uniplot(new_df1_target1, col = 'Diabetes',title = 'Distribution of Gender for NoShow Customers',hue = 'Gender')

# %%
uniplot(new_df1_target0, col = 'Diabetes',title = 'Distribution of Gender for NoShow Customers',hue = 'Gender')

# %%
uniplot(new_df1_target1, col = 'SMSReceived',title = 'Distribution of Gender for NoShow Customers',hue = 'Gender')

# %%
uniplot(new_df1_target0, col = 'SMSReceived',title = 'Distribution of Gender for NoShow Customers',hue = 'Gender')

# %% [markdown]
# # Findings

# %% [markdown]
# 1. Female patients have taken more appointments than male patients
# 2. Ratio of NoShow and Show is almost equal for age group except Age 0 and Age 1 with 80% Show rate for each age group
# 4. There are 99666 patients without Scholarship and out of them around 80% have come for the visit and out of the 21801            patients with Scholarship around 75% of them have come for the visit.
# 5. There are around 88,726 patients without Hypertension and out of them around 78% have come for the visit and Out of the        21801 patients with Hypertension around 85% of them have come for the visit.
# 6. There are around 102,584 patients without Diabetes and out of them around 80% have come for the visit and Out of the 7,943      patients with Diabetes around 83% of them have come for the visit.
# 7. There are around 75,045 patients who have not received SMS and out of them around 84% have come for the visit and out of the    35,482 patients who have received SMS around 72% of them have come for the visit.
# 8. There is no appointments on sunday and on saturday appointments are very less in comparision to other week days
